# %%
import pandas as pd
df = pd.read_csv('Power BI.csv')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df= df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
# create a column age_group
labels = ['Young Adult','Adult','Middle-aged','Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels=labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # create a column age_group
#       2 labels = ['Young Adult','Adult','Middle-aged','Senior']
# ----> 3 df['age_group'] = pd.qcut(df['age'], q=4, labels=labels)
#
# NameError: name 'df' is not defined

# %%
df[['age','age_group']].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df[['age','age_group']].head(10)
#
# NameError: name 'df' is not defined

# %%
# create purchase_frequency_days
frequency_mapping={
    'Fortnightly' :14,
    'Weekly':7,
    'Monthly':30,
    'Quaterly' : 90,
    'Bi-Weekly':14,
    'Annually':30,
    'Every 3 Months': 90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                     14.0            Fortnightly
# 1                     14.0            Fortnightly
# 2                      7.0                 Weekly
# 3                      7.0                 Weekly
# 4                     30.0               Annually
# 5                      7.0                 Weekly
# 6                      NaN              Quarterly
# 7                      7.0                 Weekly
# 8                     30.0               Annually
# 9                      NaN              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied']== df['promo_code_used']).all()
# Out:
# np.True_

# %%
df = df.drop('promo_code_used', axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 346.6 kB/s eta 0:00:07
#    ------- -------------------------------- 0.5/2.7 MB 346.6 kB/s eta 0:00:07
#    ------- -------------------------------- 0.5/2.7 MB 346.6 kB/s eta 0:00:07
#    --------------- ------------------------ 1.0/2.7 MB 515.5 kB/s eta 0:00:04
#    ------------------- -------------------- 1.3/2.7 MB 637.0 kB/s eta 0:00:03
#    ------------------- -------------------- 1.3/2.7 MB 637.0 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.7 MB 629.9 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.7 MB 691.0 kB/s eta 0:00:02
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.2 MB/s  0:00:00
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\SKYLINE\anaconda3\python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "Aij2436558#@$" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "shopping_customers"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "customer"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      13 # Step 2: Load DataFrame into PostgreSQL
#      14 table_name = "customer"   # choose any table name
# ---> 15 df.to_sql(table_name, engine, if_exists="replace", index=False)
#      17 print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
#
# NameError: name 'df' is not defined

# %%
from sqlalchemy import create_engine
import pandas as pd  # Import pandas library

# Step 1: Define your DataFrame by loading it from your dataset
# Replace 'your_dataset.csv' with the path to your actual dataset file
df = pd.read_csv('shopping_customers.csv')  # For CSV files
# Or for Excel files: df = pd.read_excel('your_dataset.xlsx')
# Or for JSON files: df = pd.read_json('your_dataset.json')

# Step 2: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "Aij2436558#@$" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "shopping_customers"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 3: Load DataFrame into PostgreSQL
table_name = "customer"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       2 import pandas as pd  # Import pandas library
#       4 # Step 1: Define your DataFrame by loading it from your dataset
#       5 # Replace 'your_dataset.csv' with the path to your actual dataset file
# ----> 6 df = pd.read_csv('shopping_customers.csv')  # For CSV files
#       7 # Or for Excel files: df = pd.read_excel('your_dataset.xlsx')
#       8 # Or for JSON files: df = pd.read_json('your_dataset.json')
#       9
#      10 # Step 2: Connect to PostgreSQL
#      11 # Replace placeholders with your actual details
#      12 username = "postgres"      # default user
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Load dataset
df = pd.read_csv("shopping_customers.csv")   # change to your file path

# PostgreSQL connection details
username = "postgres"
password = quote_plus("Aij2436558#@$")   # encode special characters
host = "localhost"
port = "5432"
database = "shopping_customers"

# Create connection
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Upload dataframe to PostgreSQL
table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print("Data successfully loaded into PostgreSQL table.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       3 from urllib.parse import quote_plus
#       5 # Load dataset
# ----> 6 df = pd.read_csv("shopping_customers.csv")   # change to your file path
#       8 # PostgreSQL connection details
#       9 username = "postgres"
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Load dataset from Desktop
df = pd.read_csv(r"C:\Users\SKYLINE\Desktop\shopping_customers.csv")

# PostgreSQL connection details
username = "postgres"
password = quote_plus("Aij2436558#@$")
host = "localhost"
port = "5432"
database = "shopping_customers"

# Create connection
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Upload dataframe to PostgreSQL
df.to_sql("customer", engine, if_exists="replace", index=False)

print("Data successfully loaded into PostgreSQL.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 from urllib.parse import quote_plus
#       5 # Load dataset from Desktop
# ----> 6 df = pd.read_csv(r"C:\Users\SKYLINE\Desktop\shopping_customers.csv")
#       8 # PostgreSQL connection details
#       9 username = "postgres"
#
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd  # Import pandas library

# Step 1: Define your DataFrame by loading it from your dataset
# Replace 'your_dataset.csv' with the path to your actual dataset file
df = pd.read_csv('shopping_customers.csv')  # For CSV files
# Or for Excel files: df = pd.read_excel('your_dataset.xlsx')
# Or for JSON files: df = pd.read_json('your_dataset.json')

# Step 2: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "Aij2436558#@$" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "shopping_customers"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 3: Load DataFrame into PostgreSQL
table_name = "customer"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd
from urllib.parse import quote_plus

# Step 1: Load dataset from Desktop
df = pd.read_csv(r"C:\Users\SKYLINE\Desktop\shopping_customers.csv")

# Step 2: PostgreSQL connection details
username = "postgres"
password = quote_plus("Aij2436558#@$")  # encode special characters
host = "localhost"
port = "5432"
database = "shopping_customers"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 3: Load DataFrame into PostgreSQL
table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'shopping_customers'.
